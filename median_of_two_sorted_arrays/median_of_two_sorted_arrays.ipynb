# %% [markdown]
# # The median of two sorted arrays
#
# In this notebook I develop a solution to the Leetcode problem https://leetcode.com/problems/median-of-two-sorted-arrays/

# %% [markdown]
# ## 1. Problem statement
#
# Given two sorted arrays `nums1` of length `n` and `nums2` of length `m`, obtain the median of the joint array with at most `O(m+n)` time complexity.

# %% [markdown]
# ## 2. General form of the solution
#
# `length(nums1) = m`
#
# `length(nums2) = n`
#
# `0 <= m <= 1000`
#
# `0 <= n <= 1000`
#
# `1 <= m + n <= 2000`
#
# `-106 <= nums1[i], nums2[i] <= 106`
#
# INPUT: nums1 (array of int), nums2 (array of int)
# OUTPUT: median (float)

# %%
def findMedianSortedArrays(nums1, nums2):
    pass

# %% [markdown]
# ## 3. Bruteforce solution and construction of test cases
#
# As the main goal is complexity reduction, a good first step is to use built-in functions to check and construct test-cases. To achieve this goal, we utilize numpy.
#
# The reader should note that if this problem would appear in practice this would be how to solve this problem. Numpy was fully written in C and thus will beat any python algorithm with ease

# %%
import numpy as np

# %%
def findMedianSortedArrays_brute(nums1, nums2):
    return np.median(np.append(nums1,nums2))

# %% [markdown]
# check with a simple test case now

# %%
nums1 = [1,1,1,2,3,6,14,28,19]
nums2 = [1,2,3]
print(np.sort(np.append(nums1,nums2)))
print(findMedianSortedArrays_brute(nums1, nums2))
# Out:
# [ 1  1  1  1  2  2  3  3  6 14 19 28]
# 2.5

# %% [markdown]
# ### 3.1 List of potential edge cases
#
# 1. nums1/nums2 is empty. (Note that by default at least one list needs to be non-empty.)
# 2. Both lists are equal.
# 3. The median sits at the end/beginning of nums1/nums2.
# 4. nums1/nums2 contains only one element.
# 5. nums1/nums2 are both very long.
# 6. ...
#
# Consider further test cases later on.

# %% [markdown]
# ### 3.2 Generating a list of test cases

# %%
tests = []
# Test cases taken from leetcode
test0 = {
    'input': {
        'nums1': [1,3],
        'nums2': [2]
    },
    'output': 2.0
}
test1 = {
    'input': {
        'nums1': [1,2],
        'nums2': [3,4]
    },
    'output': 2.5
}
test2 = {
    'input': {
        'nums1': [0,0],
        'nums2': [0,0]
    },
    'output': 0.0
}
test3 = {
    'input': {
        'nums1': [1],
        'nums2': []
    },
    'output': 1.0
}
test4 = {
    'input': {
        'nums1': [],
        'nums2': [2]
    },
    'output': 2.0
}

tests.append(test0)
tests.append(test1)
tests.append(test2)
tests.append(test3)
tests.append(test4)
np.random.seed(42)
nums1_1 = np.random.randint(low=-106, high=106, size=700, dtype=int)
nums2_1 = np.random.randint(low=-106, high=106, size=720, dtype=int)
nums1_2 = np.random.randint(low=-106, high=106, size=700, dtype=int)
nums2_2 = np.random.randint(low=-106, high=106, size=720, dtype=int)

test5 = {
    'input': {
        'nums1': list(np.sort(nums1_1)),
        'nums2': list(np.sort(nums2_1))
    },
    'output': findMedianSortedArrays_brute(nums1_1, nums2_1)
}
test6 = {
    'input': {
        'nums1': list(np.sort(nums1_2)),
        'nums2': list(np.sort(nums2_2))
    },
    'output': findMedianSortedArrays_brute(nums1_2, nums2_2)
}

tests.append(test5)
tests.append(test6)
np.random.seed(42)
nums1_1 = np.random.randint(low=-106, high=-96, size=700, dtype=int)
nums2_1 = np.random.randint(low=7, high=92, size=720, dtype=int)
nums1_2 = np.random.randint(low=18, high=29, size=700, dtype=int)
nums2_2 = np.random.randint(low=-82, high=-55, size=720, dtype=int)

test7 = {
    'input': {
        'nums1': list(np.sort(nums1_1)),
        'nums2': list(np.sort(nums2_1))
    },
    'output': findMedianSortedArrays_brute(nums1_1, nums2_1)
}
test8 = {
    'input': {
        'nums1': list(np.sort(nums1_2)),
        'nums2': list(np.sort(nums2_2))
    },
    'output': findMedianSortedArrays_brute(nums1_2, nums2_2)
}

tests.append(test7)
tests.append(test8)

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian
from jovian.pythondsa import evaluate_test_cases

results = evaluate_test_cases(findMedianSortedArrays_brute, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'nums1': [1, 3], 'nums2': [2]}
#
# Expected Output:
# 2.0
#
#
# Actual Output:
# 2.0
#
# Execution Time:
# 0.3 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'nums1': [1, 2], 'nums2': [3, 4]}
#
# Expected Output:
# 2.5
#
#
# Actual Output:
# 2.5
#
# Execution Time:
# 0.095 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'nums1': [0, 0], 'nums2': [0, 0]}
#
# Expected Output:
# 0.0
#
#
# Actual Output:
# 0.0
#
# Execution Time:
# 0.14 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'nums1': [1], 'nums2': []}
#
# Expected Output:
# 1.0
#
#
# Actual Output:
# 1.0
#
# Execution Time:
# 0.152 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'nums1': [], 'nums2': [2]}
#
# Expected Output:
# 2.0
#
#
# Actual Output:
# 2.0
#
# Execution Time:
# 0.081 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
#
# Input:
# {'nums1': [-106, -106, -106, -105, -105, -105, -105, -105, -104, -104, -103, -103, -103, -102, -102,...
#
# Expected Output:
# 1.5
#
#
# Actual Output:
# 1.5
#
# Execution Time:
# 1.327 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #6
#
# Input:
# {'nums1': [-106, -105, -105, -105, -104, -104, -104, -103, -103, -103, -103, -102, -102, -102, -102,...
#
# Expected Output:
# -2.0
#
#
# Actual Output:
# -2.0
#
# Execution Time:
# 0.361 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #7
#
# Input:
# {'nums1': [-106, -106, -106, -106, -106, -106, -106, -106, -106, -106, -106, -106, -106, -106, -106,...
#
# Expected Output:
# 7.0
#
#
# Actual Output:
# 7.0
#
# Execution Time:
# 0.111 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #8
#
# Input:
# {'nums1': [18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 1...
#
# Expected Output:
# -56.0
#
#
# Actual Output:
# -56.0
#
# Execution Time:
# 0.364 ms
#
# Test Result:
# PASSED
#
#
# SUMMARY
#
# TOTAL: 9, PASSED: 9, FAILED: 0

# %% [markdown]
# ## 4. Algorithm design
#
# 1. Compute `n=len(nums1)` and `m=len(nums2)`.
#     * Compare the medians of the two lists. Maybe they are already the same.
#     * Check if one of the two lists is empty.
#
#
# 2. Setup a binary search algorithm.
#
#     * Check if `n+m` is odd or even.
#     * The initial stepsize is set with `min(n,m)//4`.
#     * Setup a function to check if the median was found.
#
#
# 3. Start iteration
#
#     * Check where to move.
#     * move the median positions in oposite directions.
#     * cut step_size by half until you reach 1.

# %%
def EvaluateMedianGuess(nums1,nums2,mid1,mid2):
    # This function evaluates the median guess pair (mid1,mid2).
    # The return spectrum is ('found','left','right').
    # 'found': indicates (mid1,mid2) is a good match.
    # 'left': mid1 moves left and mid2 moves right.
    # 'right': the inverse of left.
    
    # Get the current values of the common median guess from mid1 and mid2
    median1 = nums1[mid1]
    median2 = nums2[mid2]
    
    # Necessary condition for median1 and median2 to be in the direct vicinity of the common median
    mid1_fits = (median1 >= nums2[mid2-1]) and (median1 <= nums2[mid2+1])
    mid2_fits = (median2 >= nums1[mid1-1]) and (median2 <= nums1[mid1+1])
    
    # If true. Check for the actuall median.
    if mid1_fits and mid2_fits:
        #Left and right are the count of elements to the left and right of median1 and median2
        left = mid1+mid2
        right = len(nums1)+len(nums2)-2-left
        
        # Combine the two medians into a single, sorted array
        if median1>=median2:
            mid = [median2, median1]
        else:
            mid = [median1, median2]
            
        # make sure that both the left and right side of the mid list are equal in length
        while left!=right:
            
            # running indices to take elements from the left or right of the mid list
            jl1 = 1
            jl2 = 1
            jr1 = 1
            jr2 = 1
            
            if left<right:
                right += -1
                #take the smallest element of the right side and add it to the mid list
                if nums1[mid1+jr1]>=nums2[mid2+jr2]:
                    mid.append(nums2[mid2+jr2])
                    jr2 += 1
                else:
                    mid.append(nums1[mid1+jr1])
                    jr1 += 1
            else:
                left += -1
                # take the largest element on the left side and add it to the mid list
                if nums1[mid1-jl1]<=nums2[mid2-jl2]:
                    mid.insert(0,nums2[mid2-jl2])
                    jl2 += 1
                else:
                    mid.insert(0,nums1[mid1-jl1])
                    jl1 += 1
        
        l = len(mid)
        if l%2==0:
            return "found", (mid[l//2]+mid[l//2-1])/2
        else:
            return "found", mid[l//2]
        
    # if mid1 and mid2 are not candidates for median positions, determine where to move relative to mid1/nums1.
    if median1>median2:
        return "left", None
    else:
        return "right", None

# %%
def findMedianSortedArrays(nums1, nums2):
    # get the length
    n = len(nums1)
    m = len(nums2)
    
    # Checking special cases
    # Check if one of the two lists is empty 
    if n==0:
        if m%2==1:
            return nums2[m//2]
        else:
            return (nums2[m//2]+nums2[m//2-1])/2
        
    if m==0:
        if n%2==1:
            return nums1[n//2]
        else:
            return (nums1[n//2]+nums1[n//2-1])/2
    
    # Check if the two lists are sorted relative to each other.
    if nums1[-1]<nums2[0]:
        nums = nums1 + nums2
        n = len(nums)
        if n%2==1:
            return nums[n//2]
        else:
            return (nums[n//2]+nums[n//2-1])/2
    
    if nums1[0]>nums2[-1]:
        nums = nums2 + nums1
        n = len(nums)
        if n%2==1:
            return nums[n//2]
        else:
            return (nums[n//2]+nums[n//2-1])/2
        
    # get the middle 
    mid1 = n//2
    mid2 = m//2
    
    # check medians
    if n%2==1:
        median1 = nums1[mid1]
    else:
        median1 = (nums1[mid1]+nums1[mid1-1])/2
    if m%2==1:
        median2 = nums2[mid2]
    else:
        median2 = (nums2[mid2]+nums2[mid2-1])/2
        
    # if you got lucky this is the median.
    if median1==median2:
        return median1
    
    # get the stepsize. It needs to be the minimum of the two medians
    step_size = max(min(mid1,mid2)//4,1)
    
    while True:
        # compare the median locations
        move, median = EvaluateMedianGuess(nums1,nums2,mid1,mid2)
        
        # evaluate the comparison.
        if move=="found":
            return median
        elif move=="right":
            mid1 += step_size
            mid2 += -step_size
        elif move=="left":
            mid1 += -step_size
            mid2 += step_size
            
        # Ensuring that both mid1 and mid2 are valid.
        if mid1>=n:
            mid1=n-1
        elif mid1<0:
            mid1=0
        if mid2>=m:
            mid2=m-1
        elif mid2<0:
            mid2=0
            
        # Reduce the step size for the next step.
        step_size = max(step_size//2,1)

# %%
results = evaluate_test_cases(findMedianSortedArrays, tests)
# Out:
# TEST CASE #0
#
# Input:
# {'nums1': [1, 3], 'nums2': [2]}
#
# Expected Output:
# 2.0
#
#
# Actual Output:
# 2.0
#
# Execution Time:
# 0.007 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #1
#
# Input:
# {'nums1': [1, 2], 'nums2': [3, 4]}
#
# Expected Output:
# 2.5
#
#
# Actual Output:
# 2.5
#
# Execution Time:
# 0.004 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #2
#
# Input:
# {'nums1': [0, 0], 'nums2': [0, 0]}
#
# Expected Output:
# 0.0
#
#
# Actual Output:
# 0.0
#
# Execution Time:
# 0.006 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #3
#
# Input:
# {'nums1': [1], 'nums2': []}
#
# Expected Output:
# 1.0
#
#
# Actual Output:
# 1
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #4
#
# Input:
# {'nums1': [], 'nums2': [2]}
#
# Expected Output:
# 2.0
#
#
# Actual Output:
# 2
#
# Execution Time:
# 0.002 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #5
# median1 = 4 for mid1 = 350 with [3, 4, 4, 4, 4, 5, 5]
# median2 = -1 for mid2 = 360 with [-2, -2, -1, -1, 0, 0, 0]
# median1 = -19 for mid1 = 263 with [-21, -21, -20, -19, -19, -19, -18]
# median2 = 25 for mid2 = 447 with [24, 25, 25, 25, 25, 25, 25]
# median1 = -8 for mid1 = 306 with [-8, -8, -8, -8, -8, -8, -8]
# median2 = 11 for mid2 = 404 with [10, 10, 10, 11, 11, 11, 11]
# median1 = -4 for mid1 = 327 with [-4, -4, -4, -4, -4, -3, -3]
# median2 = 6 for mid2 = 383 with [4, 5, 5, 6, 6, 6, 6]
# median1 = -2 for mid1 = 337 with [-3, -3, -2, -2, -1, -1, 0]
# median2 = 3 for mid2 = 373 with [2, 2, 3, 3, 4, 4, 4]
# median1 = 1 for mid1 = 342 with [-1, 0, 1, 1, 1, 2, 2]
# median2 = 2 for mid2 = 368 with [1, 2, 2, 2, 2, 2, 2]
# median1 = 2 for mid1 = 344 with [1, 1, 1, 2, 2, 2, 3]
# median2 = 2 for mid2 = 366 with [0, 1, 1, 2, 2, 2, 2]
# difference is left-right=2
# difference is left-right=1
# [1, 1, 2, 2]
#
# Input:
# {'nums1': [-106, -106, -106, -105, -105, -105, -105, -105, -104, -104, -103, -103, -103, -102, -102,...
#
# Expected Output:
# 1.5
#
#
# Actual Output:
# 1.5
#
# Execution Time:
# 0.492 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #6
# median1 = -4 for mid1 = 350 with [-6, -5, -5, -4, -4, -4, -4]
# median2 = 0 for mid2 = 360 with [-1, -1, 0, 0, 1, 1, 1]
# median1 = 23 for mid1 = 437 with [23, 23, 23, 23, 24, 24, 24]
# median2 = -27 for mid2 = 273 with [-29, -28, -28, -27, -27, -27, -27]
# median1 = 10 for mid1 = 394 with [9, 10, 10, 10, 10, 11, 11]
# median2 = -14 for mid2 = 316 with [-15, -15, -14, -14, -14, -14, -13]
# median1 = 2 for mid1 = 373 with [1, 2, 2, 2, 2, 3, 3]
# median2 = -7 for mid2 = 337 with [-8, -8, -8, -7, -7, -7, -6]
# median1 = 0 for mid1 = 363 with [-1, -1, 0, 0, 0, 0, 1]
# median2 = -4 for mid2 = 347 with [-5, -5, -5, -4, -3, -3, -2]
# median1 = -3 for mid1 = 358 with [-4, -3, -3, -3, -2, -1, -1]
# median2 = -2 for mid2 = 352 with [-3, -2, -2, -2, -2, -2, -1]
# median1 = -1 for mid1 = 360 with [-3, -3, -2, -1, -1, 0, 0]
# median2 = -2 for mid2 = 350 with [-4, -3, -3, -2, -2, -2, -2]
# median1 = -2 for mid1 = 359 with [-3, -3, -3, -2, -1, -1, 0]
# median2 = -2 for mid2 = 351 with [-3, -3, -2, -2, -2, -2, -2]
# difference is left-right=2
# difference is left-right=1
# [-2, -2, -2, -2]
#
# Input:
# {'nums1': [-106, -105, -105, -105, -104, -104, -104, -103, -103, -103, -103, -102, -102, -102, -102,...
#
# Expected Output:
# -2.0
#
#
# Actual Output:
# -2.0
#
# Execution Time:
# 0.318 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #7
#
# Input:
# {'nums1': [-106, -106, -106, -106, -106, -106, -106, -106, -106, -106, -106, -106, -106, -106, -106,...
#
# Expected Output:
# 7.0
#
#
# Actual Output:
# 7.0
#
# Execution Time:
# 0.02 ms
#
# Test Result:
# PASSED
#
#
# TEST CASE #8
#
# Input:
# {'nums1': [18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 18, 1...
#
# Expected Output:
# -56.0
#
#
# Actual Output:
# -56.0
#
# Execution Time:
# 0.013 ms
#
# Test Result:
# PASSED
#
#
# SUMMARY
#
# TOTAL: 9, PASSED: 9, FAILED: 0

# %% [markdown]
# As all tests have passed. It is time to submit the code to leetcode and evaluate the answer.

# %% [markdown]
# ## 5. Submission review and further code development.
#
# After submission a new error case was found.

# %%
test9 = {
    'input': {
        'nums1': [1,3],
        'nums2': [2,7]
    },
    'output': 2.5
}

tests.append(test9)

# %%
test10 = {
    'input': {
        'nums1': [2],
        'nums2': [1,4,7]
    },
    'output': 3.0
}

tests.append(test10)

# %%
test11 = {
    'input': {
        'nums1': [2],
        'nums2': [1,3,4,5]
    },
    'output': 3.0
}

tests.append(test11)

# %%
test12 = {
    'input': {
        'nums1': [2,5],
        'nums2': [1,3,4]
    },
    'output': 3.0
}

tests.append(test12)

# %%
results = evaluate_test_cases(findMedianSortedArrays, [tests[-1]])
# Out:
# TEST CASE #0
# median1 = 3 for mid1 = 1 with [1, 3]
# median2 = 7 for mid2 = 1 with [2, 7]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-b177da08a091> in <module>
# ----> 1 results = evaluate_test_cases(findMedianSortedArrays, [tests[-1]])
#
# ~\anaconda3\lib\site-packages\jovian\pythondsa\__init__.py in evaluate_test_cases(function, test_cases, error_only, summary_only)
#      85         if not error_only:
#      86             print("\n\033TEST CASE #{}\033".format(i))
# ---> 87         result = evaluate_test_case(function, test_case, display=False)
#      88         results.append(result)
#      89         if error_only and not result[1]:
#
# ~\anaconda3\lib\site-packages\jovian\pythondsa\__init__.py in evaluate_test_case(function, test_case, display)
#      63
#      64     start = timer()
# ---> 65     actual_output = function(**inputs)
#      66     end = timer()
#      67
#
# <ipython-input-25-d3b984b67caf> in findMedianSortedArrays(nums1, nums2)
#      60         #print(step_size)
#      61         # compare the median locations
# ---> 62         move, median = EvaluateMedianGuess(nums1,nums2,mid1,mid2)
#      63         #print(move)
#      64         # evaluate the comparison.
#
# <ipython-input-20-d7967adf5923> in EvaluateMedianGuess(nums1, nums2, mid1, mid2)
#      14     # Check if median1 and median2 are potential candidates for the median.
#      15     # This can only be if the following condition is met.
# ---> 16     mid1_fits = (median1 >= nums2[mid2-1]) and (median1 <= nums2[mid2+1])
#      17     mid2_fits = (median2 >= nums1[mid1-1]) and (median2 <= nums1[mid1+1])
#      18     if mid1_fits and mid2_fits:
#
# IndexError: list index out of range

# %% [markdown]
# After inspecting the error message from the test case following can be observed. When one of the two arrays is only 2 elements long, the function "EvaluateMedianGuess" is not working properly. This indicates that the function is not well designed to handle the case when mid1 or mid2 are at either end of the array. To solve this problem another conditional should be employed.
#
# The updated functions will be denoted by "_updated".
#
# Additionally, the special case of either list being made up of a single element was highlighted. This should be handled as a simple exception in the beginning of the function, due to the fact that it can be solved very efficiently without the binary search algorithm.

# %%
def EvaluateMedianGuess_updated(nums1,nums2,mid1,mid2):
    # This function evaluates the median guess pair (mid1,mid2).
    # The return spectrum is ('found','left','right').
    # 'found': indicates (mid1,mid2) is a good match.
    # 'left': mid1 moves left and mid2 moves right.
    # 'right': the inverse of left.
    
    # Get the current values of the common median guess from mid1 and mid2
    median1 = nums1[mid1]
    median2 = nums2[mid2]
    
    # Necessary condition for median1 and median2 to be in the direct vicinity of the common median
    if mid1==0:
        mid2_fits = (median2 <= nums1[mid1+1])
    elif mid1==len(nums1)-1:
        mid2_fits = (median2 >= nums1[mid1-1])
    else:
        mid2_fits = (median2 >= nums1[mid1-1]) and (median2 <= nums1[mid1+1])
    if mid2==0:
        mid1_fits = (median1 <= nums2[mid2+1])
    elif mid2==len(nums2)-1:
        mid1_fits = (median1 >= nums2[mid2-1])
    else:
        mid1_fits = (median1 >= nums2[mid2-1]) and (median1 <= nums2[mid2+1])
    
    
    # If true. Check for the actuall median.
    if mid1_fits and mid2_fits:
        #Left and right are the count of elements to the left and right of median1 and median2
        left = mid1+mid2
        right = len(nums1)+len(nums2)-2-left
        
        # Combine the two medians into a single, sorted array
        if median1>=median2:
            mid = [median2, median1]
        else:
            mid = [median1, median2]
            
        # make sure that both the left and right side of the mid list are equal in length
        while left!=right:
            
            # running indices to take elements from the left or right of the mid list
            jl1 = 1
            jl2 = 1
            jr1 = 1
            jr2 = 1
            
            if left<right:
                right += -1
                #take the smallest element of the right side and add it to the mid list
                if nums1[mid1+jr1]>=nums2[mid2+jr2]:
                    mid.append(nums2[mid2+jr2])
                    jr2 += 1
                else:
                    mid.append(nums1[mid1+jr1])
                    jr1 += 1
            else:
                left += -1
                # take the largest element on the left side and add it to the mid list
                if nums1[mid1-jl1]<=nums2[mid2-jl2]:
                    mid.insert(0,nums2[mid2-jl2])
                    jl2 += 1
                else:
                    mid.insert(0,nums1[mid1-jl1])
                    jl1 += 1
        
        l = len(mid)
        if l%2==0:
            return "found", (mid[l//2]+mid[l//2-1])/2
        else:
            return "found", mid[l//2]
        
    # if mid1 and mid2 are not candidates for median positions, determine where to move relative to mid1/nums1.
    if median1>median2:
        return "left", None
    else:
        return "right", None

def shiftedMedian(nums,a):
    # compute the median in the special case of one of the two lists only holding one element
    n = len(nums)
    mid = n//2
    
    if n%2==0:
        if a<nums[mid-1]:
            return nums[mid-1]
        elif a>nums[mid]:
            return nums[mid]
        else:
            return a
    else:
        if a<nums[mid-1]:
            return (nums[mid-1]+nums[mid])/2
        elif a>nums[mid+1]:
            return (nums[mid]+nums[mid+1])/2
        else:
            return (a+nums[mid])/2
    
def findMedianSortedArrays_updated(nums1, nums2):
    # get the length
    n = len(nums1)
    m = len(nums2)
    
    # Checking special cases
    # Check if one of the two lists is empty 
    if n==0:
        if m%2==1:
            return nums2[m//2]
        else:
            return (nums2[m//2]+nums2[m//2-1])/2
    elif m==0:
        if n%2==1:
            return nums1[n//2]
        else:
            return (nums1[n//2]+nums1[n//2-1])/2
    elif n==1:
        return shiftedMedian(nums2,nums1[0])
    elif m==1:
        return shiftedMedian(nums1,nums2[0])
    

    # Check if the two lists are sorted relative to each other.
    if nums1[-1]<nums2[0]:
        nums = nums1 + nums2
        n = len(nums)
        if n%2==1:
            return nums[n//2]
        else:
            return (nums[n//2]+nums[n//2-1])/2
    
    if nums1[0]>nums2[-1]:
        nums = nums2 + nums1
        n = len(nums)
        if n%2==1:
            return nums[n//2]
        else:
            return (nums[n//2]+nums[n//2-1])/2

    # get the middle 
    mid1 = n//2
    mid2 = m//2
    '''
    # check medians
    if n%2==1:
        median1 = nums1[mid1]
    else:
        median1 = (nums1[mid1]+nums1[mid1-1])/2
    if m%2==1:
        median2 = nums2[mid2]
    else:
        median2 = (nums2[mid2]+nums2[mid2-1])/2
        
    # if you got lucky this is the median.
    if median1==median2:
        return median1
    '''
    # get the stepsize. It needs to be the minimum of the two medians
    step_size = max(min(mid1,mid2)//4,1)
    
    while True:
        # compare the median locations
        move, median = EvaluateMedianGuess_updated(nums1,nums2,mid1,mid2)
        print(f"mid1={mid1}")
        print(f"mid2={mid2}")
        # evaluate the comparison.
        if move=="found":
            return median
        elif move=="right":
            mid1 += step_size
            mid2 += -step_size
        elif move=="left":
            mid1 += -step_size
            mid2 += step_size
            
        # Ensuring that both mid1 and mid2 are valid.
        if mid1>=n:
            mid1=n-1
        elif mid1<0:
            mid1=0
        if mid2>=m:
            mid2=m-1
        elif mid2<0:
            mid2=0
            
        # Reduce the step size for the next step.
        step_size = max(step_size//2,1)

# %%
results = evaluate_test_cases(findMedianSortedArrays_updated, [tests[-1]])
# Out:
# TEST CASE #0
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# ...
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# mid2=1
# mid1=0
# mid2=2
# mid1=1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-fb29bbaaf9a6> in <module>
# ----> 1 results = evaluate_test_cases(findMedianSortedArrays_updated, [tests[-1]])
#
# ~\anaconda3\lib\site-packages\jovian\pythondsa\__init__.py in evaluate_test_cases(function, test_cases, error_only, summary_only)
#      85         if not error_only:
#      86             print("\n\033TEST CASE #{}\033".format(i))
# ---> 87         result = evaluate_test_case(function, test_case, display=False)
#      88         results.append(result)
#      89         if error_only and not result[1]:
#
# ~\anaconda3\lib\site-packages\jovian\pythondsa\__init__.py in evaluate_test_case(function, test_case, display)
#      63
#      64     start = timer()
# ---> 65     actual_output = function(**inputs)
#      66     end = timer()
#      67
#
# <ipython-input-59-bcc307b09707> in findMedianSortedArrays_updated(nums1, nums2)
#     161         # compare the median locations
#     162         move, median = EvaluateMedianGuess_updated(nums1,nums2,mid1,mid2)
# --> 163         print(f"mid1={mid1}")
#     164         print(f"mid2={mid2}")
#     165         # evaluate the comparison.
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~\anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# ~\anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     489                                  copy_threshold=self.copy_threshold)
#     490             data.group = group
# --> 491         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     492
#     493     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
